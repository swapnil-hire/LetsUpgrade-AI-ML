# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
df=pd.read_csv("general_data.csv") 
df.head(2)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df["NumCompaniesWorked"].fillna(df['NumCompaniesWorked'].mean(),inplace=True)
df["TotalWorkingYears"].fillna(df['TotalWorkingYears'].mean(),inplace=True)
df.drop(['EmployeeID', 'EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)

# %%
df['Attrition'].replace({'No': 0, 'Yes': 1},inplace = True)
df['Gender'].replace({'Female': 0, 'Male': 1},inplace = True)
df['Department'].replace({'Sales': 0, 'Research & Development': 1, 'Human Resources' : 2},inplace = True)
df['EducationField'].replace({'Life Sciences': 0, 'Other': 1, 'Marketing' : 2, 'Medical':3, 'Technical Degree':4, 'Human Resources' : 5 },inplace = True)
df['BusinessTravel'].replace({'Travel_Rarely': 3, 'Travel_Frequently': 2,'Non-Travel': 1},inplace = True)

# %%
df.head(4)
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               3           0                 6          2
# 1   31          1               2           1                10          1
# 2   32          0               2           1                17          4
# 3   38          0               1           1                 2          5
#
#    EducationField  Gender  JobLevel                    JobRole MaritalStatus  \
# 0               0       0         1  Healthcare Representative       Married
# 1               0       0         1         Research Scientist        Single
# 2               1       1         4            Sales Executive       Married
# 3               0       1         3            Human Resources       Married
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 0         131160                 1.0                 11                 0
# ...

# %%
from scipy.stats import pearsonr

# %%
stats,p=pearsonr(df.Attrition,df.BusinessTravel)
print(stats,p)
# Out:
# 7.377694602222606e-05 0.9960919945440154

# %%
stats,p=pearsonr(df.Attrition,df.Department)
print(stats,p)
# Out:
# 0.04820581991833704 0.0013638319632114106

# %%
stats,p=pearsonr(df.Attrition,df.DistanceFromHome)
print(stats,p)
# Out:
# -0.009730141010179438 0.5182860428049617

# %%
st,q=pearsonr(df.Attrition,df.EducationField)
print(st,q)
# Out:
# 0.0049707002330168955 0.7413985395371094

# %%
st3,g=pearsonr(df.Attrition,df.Education)
st4,m=pearsonr(df.Attrition,df.EducationField)
st5,n=pearsonr(df.Attrition,df.Gender)
st6,s=pearsonr(df.Attrition,df.NumCompaniesWorked)
st7,l=pearsonr(df.Attrition,df.PercentSalaryHike)
st8,gg=pearsonr(df.Attrition,df.TotalWorkingYears)
st9,mm=pearsonr(df.Attrition,df.TrainingTimesLastYear)
st10,nn=pearsonr(df.Attrition,df.YearsAtCompany)
st11,ss=pearsonr(df.Attrition,df.YearsSinceLastPromotion)
st12,ll=pearsonr(df.Attrition,df.YearsWithCurrManager)

# %%
print(st3,g)
print(st4,m)
print(st5,n)
print(st6,s)
print(st7,l)
print(st3,gg)
print(st8,mm)
print(st9,nn)
print(st10,ss)
print(st11,ll)
# Out:
# -0.015111167710968737 0.3157293177118575
# 0.0049707002330168955 0.7413985395371094
# 0.01812507887701033 0.22881970951790567
# 0.04223152661444658 0.005032276452667087
# 0.032532594891052195 0.030743386433369824
# -0.015111167710968737 5.473147954406791e-30
# -0.17011136633026647 0.001024706191536548
# -0.049430576244253066 3.163883122493571e-19
# -0.13439221398997386 0.02833033618939086
# -0.03301877514258329 1.7339322652951965e-25

# %%
df.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751    0.010846
# Attrition               -0.159205   1.000000        0.000074    0.048206
# BusinessTravel           0.024751   0.000074        1.000000    0.010982
# Department               0.010846   0.048206        0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616   -0.012134
# Education               -0.035706  -0.015111        0.002755    0.004597
# EducationField           0.009023   0.004971        0.016137    0.082308
# Gender                  -0.039352   0.018125       -0.039243   -0.003158
# JobLevel                -0.002884  -0.010290        0.046111   -0.002923
# MonthlyIncome           -0.044314  -0.031176       -0.037597    0.032237
# NumCompaniesWorked       0.298528   0.042232        0.022365    0.003945
# PercentSalaryHike       -0.033137   0.032533       -0.031054    0.007840
# ...
