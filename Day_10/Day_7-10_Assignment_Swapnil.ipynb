# %% [markdown]
# # Assignment Day 10
#
# Single employees tend to leave compared to married and divorced
# Sales Representitives tend to leave compared to any other job
# Less involved employees tend to leave the company
# Less experienced (low job level) tend to leave the company
# We can observe that from age 29-31 max people are leaving the company
# the number of Male employes is more than Female.
# the job level 1 is has higher percentage than.
# the Number of employes in Sales Executive job role is more than other job role.
# Attrition raltes are high in these attribute Sales Deparment, Male,Jobsatisfaction 1
# Employee are more likely to quit , When DistanceFromHome is above 8KM and (Married people are higher in this case )
# DistanceFromHome is above 2.5 for JobLevel 5

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
df=pd.read_csv("general_data.csv") 
df.head(4)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df["NumCompaniesWorked"].fillna(df['NumCompaniesWorked'].mean(),inplace=True)
df["TotalWorkingYears"].fillna(df['TotalWorkingYears'].mean(),inplace=True)

# %%
df.sort_values("EmployeeID", inplace = True) 
  
# dropping ALL duplicte values 
df.drop_duplicates(subset ="EmployeeID", 
                     keep = False, inplace = True) 

df.head(4)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# ...

# %%
df.drop(['EmployeeID', 'EmployeeCount','Over18'],axis=1,inplace=True)

# %%
fig = plt.figure(figsize=(20,2))
sns.countplot(y = df['Attrition'])
plt.title('Count for employee attrition')
plt.show()

# %%
df.describe()
df1=df.loc[df['Attrition'] == 'Yes']
df1.head()
df2=df.loc[df['Attrition'] == 'No']
df2.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  Gender  JobLevel                    JobRole  ...  \
# 0          2  Life Sciences  Female         1  Healthcare Representative  ...
# 2          4          Other    Male         4            Sales Executive  ...
# 3          5  Life Sciences    Male         3            Human Resources  ...
# 4          1        Medical    Male         1            Sales Executive  ...
# 5          3  Life Sciences  Female         4          Research Director  ...
#
# ...

# %%
sns.countplot(df1['Age'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %%
sns.countplot(df2['Age'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %%
sns.countplot(df1['YearsWithCurrManager'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('YearsWithCurrManager')
# Out:
# Text(0.5, 1.0, 'YearsWithCurrManager')

# %%
sns.countplot(df1['PercentSalaryHike'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('PercentSalaryHike')
# Out:
# Text(0.5, 1.0, 'PercentSalaryHike')

# %%
sns.countplot(df1['YearsAtCompany'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('YearsAtCompany')
# Out:
# Text(0.5, 1.0, 'YearsAtCompany')

# %%
sns.countplot(df2['YearsAtCompany'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('YearsAtCompany')
# Out:
# Text(0.5, 1.0, 'YearsAtCompany')

# %%
sns.countplot(df1['MaritalStatus'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Marital Status')
# Out:
# Text(0.5, 1.0, 'Marital Status')

# %%
plt.subplots(figsize=(25,5))
sns.countplot(df1.TotalWorkingYears)

# %%
plt.subplots(figsize=(20,5))
sns.countplot(df1.Gender)

# %%
sns.countplot(df1['EducationField'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('EducationField')
# Out:
# Text(0.5, 1.0, 'EducationField')

# %%
sns.countplot(df1['YearsAtCompany'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('YearsAtCompany')
# Out:
# Text(0.5, 1.0, 'YearsAtCompany')

# %%
sns.countplot(df1['Department'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Department')
# Out:
# Text(0.5, 1.0, 'Department')

# %%
sns.countplot(df1['BusinessTravel'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('BusinessTravel')
# Out:
# Text(0.5, 1.0, 'BusinessTravel')

# %%
sns.countplot(df1['Gender'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Gender')
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
sns.countplot(df2['Gender'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Gender')
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
plt.figure(figsize=(15,10))
ax=sns.barplot(x=df1['JobRole'],y=df1['MonthlyIncome'])
plt.xticks(rotation=0)
plt.xlabel("JobRole")
plt.ylabel("MonthlyIncome")
plt.title("Job Roles with Monthly Income")
plt.show()

# %%
df1.hist(bins=30,figsize=(20,20),color='b')
plt.show()
